# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('../Data/attacks.csv', encoding='latin1')

# %% [markdown]
# # 1. miramos cual es el shape del dataframe para saber y tener una idea general de como es

# %%
data.shape
# Out:
# (25723, 24)

# %% [markdown]
# # 2.hacemos una copia del dataframe original para poder editarlo y limpiarlo

# %%
data_sharks = data
data_sharks.shape
# Out:
# (25723, 24)

# %% [markdown]
# # 3. vamos a ver cuantos nulos hay y si podemos borrar filas

# %%
data_sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
null_f= data_sharks.isna().sum(axis=1)
null_f.sort_values(ascending=False)
null_f
# Out:
# 0         2
# 1         3
# 2         3
# 3         4
# 4         4
#          ..
# 25718    24
# 25719    24
# 25720    24
# 25721    24
# 25722    23
# Length: 25723, dtype: int64

# %%
null_f0= null_f[null_f>20]
null_f0.index
data_sharks.drop(null_f0.index, inplace=True)

# %%
data_sharks.shape
# Out:
# (6302, 24)

# %%
data_sharks.isna().sum()
# Out:
# Case Number                  1
# Date                         0
# Year                         2
# Type                         4
# Country                     50
# Area                       455
# Location                   540
# Activity                   544
# Name                       210
# Sex                        565
# Age                       2831
# Injury                      28
# Fatal (Y/N)                539
# Time                      3354
# Species                   2838
# Investigator or Source      17
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# Unnamed: 22               6301
# Unnamed: 23               6300
# dtype: int64

# %%
data_sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# # 4. limpieza de countries, areas y location

# %%
data_country_1=data_sharks[['Country', 'Area','Location']]
data_country_1
# Out:
#                  Country               Area  \
# 0                    USA         California
# 1                    USA            Georgia
# 2                    USA             Hawaii
# 3              AUSTRALIA    New South Wales
# 4                 MEXICO             Colima
# ...                  ...                ...
# 6297           AUSTRALIA  Western Australia
# 6298           AUSTRALIA  Western Australia
# 6299                 USA     North Carolina
# 6300              PANAMA                NaN
# 6301  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location
# 0             Oceanside, San Diego County
# 1          St. Simon Island, Glynn County
# 2                            Habush, Oahu
# 3                      Arrawarra Headland
# 4                                La Ticla
# ...                                   ...
# 6297                          Roebuck Bay
# 6298                                  NaN
# 6299                       Ocracoke Inlet
# ...

# %%
data_missing_1=data_country_1[(data_country_1['Country'].isnull()) & (data_country_1['Area'].isnull()) & (data_country_1['Location'].isnull())]
data_missing_1.index
# Out:
# Index([  62,  525, 3378, 3388, 3395, 3399, 3425, 3661, 4726, 4729, 4911, 5060,
#        5586, 5587, 5636, 5770, 5839, 5885, 5920, 5996, 6001, 6092, 6119, 6131,
#        6133, 6165, 6171, 6199, 6259],
#       dtype='int64')

# %%
data_sharks.drop(data_missing_1.index, inplace=True)

# %%
data_sharks.shape
# Out:
# (6273, 24)

# %%
mapeo_Area = {
    'English Channel': 'england',
    'Caribbean Sea': 'caribe',
    'Between Timor & Darwin, Australia': 'australia',
    'Near the Andaman & Nicobar Islands': 'india',
    'Between Comores & Madagascar': 'madagascar',
    'Off South American coast':'chile',
    '300 miles east of St. Thomas (Virgin Islands)': 'usa',
    'French Southern Territories': 'france',
    'Mediterranean Sea': 'spain',
    'Gulf of California': 'mexico',
    'Western Banks': 'australia',
    'St Helena': 'australia',
    'Ionian Sea': 'italy'
 }

# %%
data_sharks[(data_sharks['Country'].isnull()) & (data_sharks['Area'].isnull())]
# Out:
#      Case Number         Date    Year          Type Country Area  \
# 3605  1965.10.21  21-Oct-1965  1965.0    Unprovoked     NaN  NaN
# 4639  1944.10.24  24-Oct-1944  1944.0  Sea Disaster     NaN  NaN
# 5425  1909.01.17  17-Jan-1909  1909.0       Invalid     NaN  NaN
# 5810  1881.06.25  25-Jul-1881  1881.0    Unprovoked     NaN  NaN
# 6155  1742.12.17  17-Dec-1742  1742.0    Unprovoked     NaN  NaN
# 6206     ND-0114  Before 2012     0.0    Unprovoked     NaN  NaN
#
#                                        Location  \
# 3605                             Florida Strait
# 4639                225 miles east of Hong Kong
# 5425                           Near the equator
# 5810                                 Santa Cruz
# 6155                               Carlisle Bay
# 6206  In a river feeding into the Bay of Bengal
#
#                                                Activity                Name  \
# 3605                           The boat Caribou II sank   Mario Castellanos
# ...

# %%
mapeo_location={
    'Florida Strait': 'usa',
    '225 miles east of Hong Kong': 'china',
    'Near the equator': 'cameroon',
    'Santa Cruz': 'usa',
    'Carlisle Bay': 'caribe',
    'In a river feeding into the Bay of Bengal':'india'
    
}

# %%
for index, row in data_sharks[data_sharks['Country'].isnull() & data_sharks['Area'].isnull() & data_sharks['Location'].notnull()].iterrows():
    if row['Location'] in mapeo_location:
        data_sharks.at[index, 'Country'] = mapeo_location[row['Location']]
        data_sharks.at[index, 'Area'] =  mapeo_location[row['Location']]

# %%
data_sharks[(data_sharks['Country'].isnull()) & (data_sharks['Location'].isnull())]
# Out:
#          Case Number                  Date    Year          Type Country  \
# 2956    1983.00.00.d              Ca. 1983  1983.0    Unprovoked     NaN
# 4018      1960.01.26           26-Jan-1960  1960.0  Sea Disaster     NaN
# 4231      1956.09.13           13-Sep-1956  1956.0    Unprovoked     NaN
# 4700    1942.11.00.a              Nov-1942  1942.0  Sea Disaster     NaN
# 4712      1942.06.00              Jun-1942  1942.0    Unprovoked     NaN
# 5612  1897.03.15.b.R  Reported 15-Mar-1897  1897.0    Unprovoked     NaN
# 5742      1887.07.30           30-Jul-1887  1887.0  Sea Disaster     NaN
# 5808    1881.08.16.R  Reported 16-Aug-1881  1881.0    Unprovoked     NaN
# 6175      0077.00.00              77  A.D.    77.0    Unprovoked     NaN
# 6177       0000.0214          Ca. 214 B.C.     0.0    Unprovoked     NaN
#
#                                                Area Location  \
# 2956                                English Channel      NaN
# ...

# %%
mapeo_Area = {
    'English Channel': 'england',
    'Between Timor & Darwin, Australia': 'australia',
    'Near the Andaman & Nicobar Islands': 'india',
    'Between Comores & Madagascar': 'madagascar',
    'Off South American coast':'chile',
    '300 miles east of St. Thomas (Virgin Islands)': 'usa',
    'Mediterranean Sea': 'spain',
    'Gulf of California': 'mexico',
    'Western Banks': 'australia',
    'Ionian Sea': 'italy'
 }

# %%
for index, row in data_sharks[data_sharks['Country'].isnull() & data_sharks['Location'].isnull() & data_sharks['Area'].notnull()].iterrows():
    if row['Area'] in mapeo_Area:
        data_sharks.at[index, 'Country'] = mapeo_Area[row['Area']]
        data_sharks.at[index, 'Location'] =  mapeo_Area[row['Area']]

# %%
null_1=data_sharks[(data_sharks['Area'].isnull()) & (data_sharks['Location'].isnull())]
null_1.index
data_sharks.drop(null_1.index, inplace=True)
data_sharks.shape
# Out:
# (6062, 24)

# %% [markdown]
# # 5 voy a limpiar la fila de country con un diccionario para que tengan nombres estandar

# %%
data_sharks['Country'] = data_sharks['Country'].str.lower()

# %%
mapeo_Pais = {
    'usa': 'usa',
    'australia': 'australia',
    'mexico': 'mexico',
    'brazil': 'brazil',
    'england': 'england',
    'south africa': 'south africa',
    'thailand': 'thailand',
    'costa rica': 'costa rica',
    'maldives': 'maldive islands',
    'bahamas': 'bahamas',
    'new caledonia': 'new caledonia',
    'ecuador': 'ecuador',
    'malaysia': 'malaysia',
    'libya': 'libya',
    'cuba': 'cuba',
    'mauritius': 'mauritius',
    'new zealand': 'new zealand',
    'spain': 'spain',
    'samoa': 'samoa',
    'solomon islands': 'solomon islands',
    'japan': 'japan',
    'egypt': 'egypt',
    'st helena, british overseas territory': 'england territory, atlantic',
    'comoros': 'comoros',
    'reunion': 'france territory, indian',
    'french polynesia': 'france territory, pacific',
    'united kingdom': 'england',
    'united arab emirates': 'united arab emirates',
    'philippines': 'philippines',
    'indonesia': 'indonesia',
    'china': 'china',
    'columbia': 'Colombia',
    'cape verde': 'cape verde',
    'fiji': 'fiji',
    'dominican republic': 'dominican republic',
    'cayman islands': 'england territory, caribe',
    'aruba': 'netherlands territory, caribe',
    'mozambique': 'mozambique',
    'puerto rico': 'puerto rico',
    'italy': 'italy',
    'greece': 'greece',
    'st. martin': 'france territory, caribe',
    'france': 'france',
    'trinidad & tobago': 'trinidad & tobago',
    'kiribati': 'kiribati',
    'israel': 'israel',
    'taiwan': 'taiwan',
    'jamaica': 'jamaica',
    'palestinian territories': 'palestinian',
    'seychelles': 'seychelles',
    'nigeria': 'nigeria',
    'tonga': 'tonga',
    'scotland': 'scotland',
    'canada': 'canada',
    'croatia': 'croatia',
    'saudi arabia': 'saudi arabia',
    'chile': 'chile',
    'antigua': 'antigua & barbuda',
    'papua new guinea': 'papua new guinea',
    'kenya': 'kenya',
    'russia': 'russia',
    'turks & caicos': 'england territory, caribe',
    'united arab emirates (uae)': 'united arab emirates',
    'azores': 'portugal',
    'south korea': 'south korea',
    'malta': 'malta',
    'vietnam': 'vietnam',
    'madagascar': 'madagascar',
    'guam': 'usa territory, pacific',
    'panama': 'panama',
    'somalia': 'somalia',
    'nevis': 'san cristóbal y nevis',
    'british virgin islands': 'england territory, caribe',
    'norway': 'norway',
    'yemen': 'yemen',
    'gulf of aden': 'yemen',
    'belize': 'belize',
    'sierra leone': 'sierra leone',
    'atlantic ocean': 'atlantic ocean',
    'st. maartin': 'netherlands territory, caribe',
    'grand cayman': 'england territory, caribe',
    'vanuatu': 'vanuatu',
    'mexico ': 'mexico',
    'honduras': 'honduras',
    'venezuela': 'venezuela',
    'sri lanka': 'sri lanka',
    ' tonga': 'tonga',
    'uruguay': 'uruguay',
    'india': 'india',
    'micronesia': 'micronesia',
    'caribbean sea': 'venezuela',
    'okinawa': 'japan',
    'tanzania': 'tanzania',
    'marshall islands': 'marshall islands',
    'senegal': 'senegal',
    'egypt / israel': 'egypt',
    'hong kong': 'hong kong',
    'el salvador': 'el salvador',
    'angola': 'angola',
    'montenegro': 'montenegro',
    'iran': 'iran',
    'tunisia': 'tunisia',
    'namibia': 'namibia',
    'north atlantic ocean': 'atlantic ocean',
    'portugal': 'portugal',
    'bangladesh': 'bangladesh',
    'palau': 'palau',
    'western samoa': 'samoa',
    'british isles': 'england',
    'grenada': 'grenada',
    'iraq': 'iraq',
    'bermuda': 'england territory, atlantic',
    'turkey': 'turkey',
    'singapore': 'singapore',
    'new britain': 'usa',
    'sudan': 'sudan',
    'pacific ocean ': 'pacific ocean',
    'new guinea': 'new guinea',
    'red sea': 'saudi arabia',
    'federated states of micronesia': 'micronesia',
    'mid atlantic ocean': 'atlantic ocean',
    'admiralty islands': 'new guinea',
    'british west indies': 'england territory, caribe',
    'south atlantic ocean': 'atlantic ocean',
    'persian gulf': 'saudi arabia',
    'north pacific ocean': 'pacific ocean',
    'red sea / indian ocean': 'saudi arabia',
    'pacific ocean': 'pacific ocean',
    'north sea': 'england',
    'nicaragua ': 'nicaragua',
    'maldive islands': 'maldive islands',
    'american samoa': 'usa territory, pacific',
    'gabon': 'gabon',
    'mayotte': 'france territory, indian',
    'north atlantic ocean ': 'atlantic ocean',
    'the balkans': 'greece',
    'sudan?': 'sudan',
    'argentina': 'argentina',
    'indian ocean': 'indian ocean',
    'netherlands antilles': 'netherlands territory, caribe',
    'liberia': 'liberia',
    'northern mariana islands': 'usa territory, atlantic',
    'iran / iraq': 'iran',
    'java': 'indonesia',
    ' philippines': 'philippines',
    'nicaragua': 'nicaragua',
    'central pacific': 'pacific ocean',
    'solomon islands / vanuatu': 'solomon islands',
    'southwest pacific ocean': 'pacific ocean',
    'mid-pacifc ocean': 'pacific ocean',
    'slovenia': 'slovenia',
    'curacao': 'netherlands territory, caribe',
    'iceland': 'iceland',
    'italy / croatia': 'italy',
    'barbados': 'barbados',
    'monaco': 'monaco',
    'guyana': 'guyana',
    'haiti': 'haiti',
    'san domingo': 'dominican republic',
    'ireland': 'ireland',
    'cameroon': 'cameroon',
    'yemen ': 'yemen',
    'reunion island': 'france territory, indian',
    'cyprus': 'cyprus',
    'egypt ': 'egypt',
    'burma': 'burma',
    'lebanon': 'lebanon',
    'martinique': 'france territory, caribe',
    'british new guinea': 'new guinea',
    'ocean': 'atlantic ocean',
    'georgia': 'georgia',
    'tuvalu': 'tuvalu',
    'guinea': 'guinea',
    'equatorial guinea / cameroon': 'cameroon',
    'cook islands': 'new zealand',
    'tobago': 'trinidad & tobago',
    'peru': 'peru',
    'algeria': 'algeria',
    'coast of africa': 'south africa',
    'tasman sea': 'australia',
    'ghana': 'ghana',
    'sweden': 'sweden',
    'caribe': 'venezuela',
    'djibouti': 'djibouti',
    'korea': 'south korea',
    'ceylon (sri lanka)': 'sri lanka'
 }

# %%
data_sharks['Country'] = data_sharks['Country'].map(mapeo_Pais)

# %%
data_sharks.Country.unique()
# Out:
# array(['usa', 'australia', 'mexico', 'brazil', 'england', 'south africa',
#        'thailand', 'costa rica', 'maldive islands', 'bahamas',
#        'new caledonia', 'ecuador', 'malaysia', 'libya', 'cuba',
#        'mauritius', 'new zealand', 'spain', 'samoa', 'solomon islands',
#        'japan', 'egypt', 'england territory, atlantic', 'comoros',
#        'france territory, indian', 'france territory, pacific',
#        'united arab emirates', 'philippines', 'indonesia', 'china',
#        'Colombia', 'cape verde', 'fiji', 'dominican republic',
#        'england territory, caribe', 'netherlands territory, caribe',
#        'mozambique', 'puerto rico', 'italy', 'greece',
#        'france territory, caribe', 'france', 'trinidad & tobago',
#        'kiribati', 'israel', 'taiwan', 'jamaica', 'palestinian',
#        'seychelles', 'nigeria', 'tonga', 'scotland', 'canada', 'croatia',
#        'saudi arabia', 'chile', 'antigua & barbuda', 'papua new guinea',
# ...

# %% [markdown]
# # 6 voy a copiar la fila de country en la fila de location y con un dicionario voy a poner los oceanos o mares donde estan

# %%
null_2=data_sharks[(data_sharks['Area'].isnull())]
null_2.index
data_sharks.drop(null_2.index, inplace=True)

# %%
data_sharks.shape
# Out:
# (5853, 24)

# %%
null_3=data_sharks[(data_sharks['Location'].isnull())]
null_3.index
data_sharks.drop(null_3.index, inplace=True)

# %%
null_4=data_sharks[(data_sharks['Country'].isnull())]
null_4.index
data_sharks.drop(null_4.index, inplace=True)

# %%
data_sharks['Location'] = data_sharks['Country']

# %%
data_sharks['Location'].unique()
# Out:
# array(['usa', 'australia', 'mexico', 'brazil', 'england', 'south africa',
#        'thailand', 'costa rica', 'maldive islands', 'bahamas', 'ecuador',
#        'malaysia', 'cuba', 'mauritius', 'new zealand', 'spain', 'samoa',
#        'japan', 'egypt', 'england territory, atlantic', 'comoros',
#        'france territory, pacific', 'united arab emirates',
#        'france territory, indian', 'philippines', 'indonesia',
#        'new caledonia', 'dominican republic', 'england territory, caribe',
#        'mozambique', 'france', 'israel', 'jamaica', 'nigeria', 'tonga',
#        'scotland', 'trinidad & tobago', 'canada', 'italy', 'saudi arabia',
#        'chile', 'taiwan', 'antigua & barbuda', 'papua new guinea',
#        'kenya', 'russia', 'seychelles', 'Colombia', 'fiji', 'south korea',
#        'vietnam', 'madagascar', 'usa territory, pacific', 'panama',
#        'solomon islands', 'croatia', 'norway', 'yemen', 'belize',
# ...

# %%
mapeo_location_oceano ={
    'usa': 'pacific ocean',
    'australia': 'pacific ocean',
    'mexico': 'caribbean sea',
    'brazil': 'atlantic ocean',
    'england': 'atlantic ocean',
    'south africa': 'atlantic ocean',
    'thailand': 'chinese sea',
    'costa rica': 'caribbean sea',
    'bahamas': 'atlantic ocean',
    'ecuador': 'pacific ocean',
    'malaysia': 'chinese sea',
    'cuba': 'caribbean sea',
    'mauritius': 'indian ocean',
    'new zealand': 'pacific ocean',
    'spain': 'mediterranean sea',
    'samoa': 'pacific ocean',
    'japan': 'pacific ocean',
    'egypt': 'mediterranean sea',
    'england territory, atlantic': 'atlantic ocean',
    'comoros': 'indian ocean',
    'france territory, pacific': 'pacific ocean',
    'united arab emirates': 'indian ocean',
    'france territory, indian': 'indian ocean',
    'philippines': 'pacific ocean',
    'indonesia': 'indian ocean',
    'new caledonia': 'pacific ocean',
    'china': 'chinese sea',
    'Colombia': 'caribbean sea',
    'cape verde': 'atlantic ocean',
    'fiji': 'pacific ocean',
    'dominican republic': 'caribbean sea',
    'england territory, caribe': 'caribbean sea',
    'mozambique': 'indian ocean',
    'italy': 'mediterranean sea',
    'france': 'atlantic ocean',
    'trinidad & tobago': 'atlantic ocean',
    'kiribati': 'pacific ocean',
    'israel': 'mediterranean sea',
    'taiwan': 'pacific ocean',
    'jamaica': 'caribbean sea',
    'nigeria': 'atlantic ocean',
    'tonga': 'pacific ocean',
    'scotland': 'atlantic ocean',
    'canada': 'pacific ocean',
    'saudi arabia': 'red sea',
    'chile': 'pacific ocean',
    'antigua & barbuda': 'caribbean sea',
    'papua new guinea': 'pacific ocean',
    'kenya': 'indian ocean',
    'russia': 'pacific ocean',
    'seychelles': 'indian ocean',
    'solomon islands': 'pacific ocean',
    'south korea': 'chinese sea',
    'vietnam': 'chinese sea',
    'madagascar': 'indian ocean',
    'usa territory, pacific': 'pacific ocean',
    'panama': 'caribbean sea',
    'croatia': 'mediterranean sea',
    'norway': 'norway sea',
    'yemen': 'indian ocean',
    'belize': 'caribbean sea',
    'sierra leone': 'atlantic ocean',
    'atlantic ocean': 'atlantic ocean',
    'netherlands territory, caribe': 'caribbean sea',
    'vanuatu': 'pacific ocean',
    'honduras': 'caribbean sea',
    'sri lanka': 'indian ocean',
    'uruguay': 'atlantic ocean',
    'venezuela': 'caribbean sea',
    'india': 'indian ocean',
    'micronesia': 'pacific ocean',
    'marshall islands': 'pacific ocean',
    'senegal': 'atlantic ocean',
    'hong kong': 'chinese sea',
    'somalia': 'indian ocean',
    'el salvador': 'pacific ocean',
    'angola': 'atlantic ocean',
    'montenegro': 'mediterranean sea',
    'greece': 'mediterranean sea',
    'tunisia': 'mediterranean sea',
    'namibia': 'atlantic ocean',
    'portugal': 'atlantic ocean',
    'bangladesh': 'indian ocean',
    'palau': 'pacific ocean',
    'iran': 'indian ocean',
    'grenada': 'caribbean sea',
    'iraq': 'indian ocean',
    'tanzania': 'indian ocean',
    'england territory, atlantic': 'atlantic ocean',
    'turkey': 'mediterranean sea',
    'sudan': 'red sea',
    'pacific ocean': 'pacific ocean',
    'new guinea': 'pacific ocean',
    'nicaragua': 'caribbean sea',
    'maldive islands': 'indian ocean',
    'gabon': 'atlantic ocean',
    'malta': 'mediterranean sea',
    'argentina': 'atlantic ocean',
    'liberia': 'atlantic ocean',
    'singapore': 'chinese sea',
    'usa territory, atlantic': 'atlantic ocean',
    'indian ocean': 'indian ocean',
    'slovenia': 'mediterranean sea',
    'iceland': 'atlantic ocean',
    'barbados': 'atlantic ocean',
    'monaco': 'mediterranean sea',
    'guyana': 'atlantic ocean',
    'haiti': 'caribbean sea',
    'ireland': 'atlantic ocean',
    'libya': 'mediterranean sea',
    'cameroon': 'atlantic ocean',
    'cyprus': 'mediterranean sea',
    'burma': 'indian ocean',
    'lebanon': 'mediterranean sea',
    'guinea': 'atlantic ocean',
    'ghana': 'atlantic ocean',
    'sweden': 'baltic sea',
    'djibouti': 'indian ocean'
 }

# %%
data_sharks['Location'] = data_sharks['Location'].map(mapeo_location_oceano)

# %%
data_sharks['Location'].unique()
# Out:
# array(['pacific ocean', 'caribbean sea', 'atlantic ocean', 'chinese sea',
#        'indian ocean', 'mediterranean sea', 'red sea', 'norway sea',
#        'baltic sea'], dtype=object)

# %% [markdown]
# # 7 aqui veo cuantos ataques hay por oceano

# %%
data_sharks['Location'].value_counts()
# Out:
# Location
# pacific ocean        4033
# atlantic ocean        845
# indian ocean          221
# mediterranean sea     208
# caribbean sea         201
# chinese sea            38
# red sea                10
# norway sea              1
# baltic sea              1
# Name: count, dtype: int64

# %% [markdown]
# # 8 voy a crear una nueva columna con el pais y el oceano/mar en el que esta pasando y eliminar las dos ultimas columnas que son todo NAN

# %%
data_sharks['pais-oceano']= data_sharks['Country']+'-'+data_sharks['Location']

# %%
data_sharks.drop(columns=['Unnamed: 22','Unnamed: 23'], inplace=True)

# %%
data_sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        usa       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        usa          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        usa           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  australia  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     mexico           Colima
#
#         Location     Activity             Name Sex   ...           Time  \
# 0  pacific ocean     Paddling      Julie Wolfe    F  ...          18h00
# 1  pacific ocean     Standing  Adyson McNeely     F  ...  14h00  -15h00
# 2  pacific ocean      Surfing      John Denges    M  ...          07h45
# 3  pacific ocean      Surfing             male    M  ...            NaN
# 4  caribbean sea  Free diving   Gustavo Ramos     M  ...            NaN
#
#           Species           Investigator or Source                       pdf  \
# ...

# %%
data_sharks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'pais-oceano'],
#       dtype='object')

# %%
data_sharks = data_sharks[['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location','pais-oceano',
       'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
       'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
       'Case Number.1', 'Case Number.2', 'original order']]

# %%
data_sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        usa       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        usa          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        usa           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  australia  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     mexico           Colima
#
#         Location              pais-oceano     Activity             Name  ...  \
# 0  pacific ocean        usa-pacific ocean     Paddling      Julie Wolfe  ...
# 1  pacific ocean        usa-pacific ocean     Standing  Adyson McNeely   ...
# 2  pacific ocean        usa-pacific ocean      Surfing      John Denges  ...
# 3  pacific ocean  australia-pacific ocean      Surfing             male  ...
# 4  caribbean sea     mexico-caribbean sea  Free diving   Gustavo Ramos   ...
#
# ...

# %%
data_sharks.isna().sum()
# Out:
# Case Number                  1
# Date                         0
# Year                         1
# Type                         2
# Country                      0
# Area                         0
# Location                     0
# pais-oceano                  0
# Activity                   430
# Name                       147
# Sex                        463
# Age                       2297
# Injury                      20
# Fatal (Y/N)                459
# Time                      2724
# Species                   2353
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# dtype: int64

# %%
data_sharks['Date']
# Out:
# 0       25-Jun-2018
# 1       18-Jun-2018
# 2       09-Jun-2018
# 3       08-Jun-2018
# 4       04-Jun-2018
#            ...
# 6292     Circa 1862
# 6296    Before 1906
# 6297    Before 1903
# 6299      1900-1905
# 6301      1845-1853
# Name: Date, Length: 5558, dtype: object

# %%
data_sharks.Time.fillna('unknown', inplace=True)
# Out:
# C:\Users\pepot\AppData\Local\Temp\ipykernel_9524\1184262207.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sharks.Time.fillna('unknown', inplace=True)

# %%
data_sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        usa       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        usa          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        usa           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  australia  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     mexico           Colima
#
#         Location              pais-oceano     Activity             Name  ...  \
# 0  pacific ocean        usa-pacific ocean     Paddling      Julie Wolfe  ...
# 1  pacific ocean        usa-pacific ocean     Standing  Adyson McNeely   ...
# 2  pacific ocean        usa-pacific ocean      Surfing      John Denges  ...
# 3  pacific ocean  australia-pacific ocean      Surfing             male  ...
# 4  caribbean sea     mexico-caribbean sea  Free diving   Gustavo Ramos   ...
#
# ...

# %%
data_sharks[['Case Number','Date', 'Year']]
# Out:
#      Case Number         Date    Year
# 0     2018.06.25  25-Jun-2018  2018.0
# 1     2018.06.18  18-Jun-2018  2018.0
# 2     2018.06.09  09-Jun-2018  2018.0
# 3     2018.06.08  08-Jun-2018  2018.0
# 4     2018.06.04  04-Jun-2018  2018.0
# ...          ...          ...     ...
# 6292     ND.0010   Circa 1862     0.0
# 6296     ND.0006  Before 1906     0.0
# 6297     ND.0005  Before 1903     0.0
# 6299     ND.0003    1900-1905     0.0
# 6301     ND.0001    1845-1853     0.0
#
# [5558 rows x 3 columns]

# %%
null_5=data_sharks[(data_sharks['Case Number'].isnull())]
null_5.index
data_sharks.drop(null_5.index, inplace=True)
# Out:
# C:\Users\pepot\AppData\Local\Temp\ipykernel_9524\2311891835.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sharks.drop(null_5.index, inplace=True)

# %%
data_sharks['Date'].unique()
# Out:
# array(['25-Jun-2018', '18-Jun-2018', '09-Jun-2018', ..., 'Before 1903',
#        '1900-1905', '1845-1853'], dtype=object)

# %%
data_sharks['Country'].unique()
# Out:
# array(['usa', 'australia', 'mexico', 'brazil', 'england', 'south africa',
#        'thailand', 'costa rica', 'maldive islands', 'bahamas', 'ecuador',
#        'malaysia', 'cuba', 'mauritius', 'new zealand', 'spain', 'samoa',
#        'japan', 'egypt', 'england territory, atlantic', 'comoros',
#        'france territory, pacific', 'united arab emirates',
#        'france territory, indian', 'philippines', 'indonesia',
#        'new caledonia', 'dominican republic', 'england territory, caribe',
#        'mozambique', 'france', 'israel', 'jamaica', 'nigeria', 'tonga',
#        'scotland', 'trinidad & tobago', 'canada', 'italy', 'saudi arabia',
#        'chile', 'taiwan', 'antigua & barbuda', 'papua new guinea',
#        'kenya', 'russia', 'seychelles', 'Colombia', 'fiji', 'south korea',
#        'vietnam', 'madagascar', 'usa territory, pacific', 'panama',
#        'solomon islands', 'croatia', 'norway', 'yemen', 'belize',
# ...

# %%
data_sharks.isna().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         1
# Type                         2
# Country                      0
# Area                         0
# Location                     0
# pais-oceano                  0
# Activity                   430
# Name                       147
# Sex                        463
# Age                       2296
# Injury                      20
# Fatal (Y/N)                459
# Time                         0
# Species                   2352
# Investigator or Source      15
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# dtype: int64

# %% [markdown]
# # 9 voy a intentar rellenar los nulos de sex y de name

# %%
data_sharks[['Name', 'Sex ']]
# Out:
#                        Name Sex
# 0               Julie Wolfe    F
# 1           Adyson McNeely     F
# 2               John Denges    M
# 3                      male    M
# 4            Gustavo Ramos     M
# ...                     ...  ...
# 6292           A "chiefess"    F
# 6296               Arab boy    M
# 6297                   male    M
# 6299  Coast Guard personnel    M
# 6301                   male    M
#
# [5557 rows x 2 columns]

# %%
null_6=data_sharks[(data_sharks['Name'].isnull()) & (data_sharks['Sex '].isnull())]
null_6.index
data_sharks.drop(null_6.index, inplace=True)
# Out:
# C:\Users\pepot\AppData\Local\Temp\ipykernel_9524\3989163053.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sharks.drop(null_6.index, inplace=True)

# %%
data_sharks.shape
# Out:
# (5459, 23)

# %%
pd.set_option('display.max_columns', None)

# %%
data_sharks[(data_sharks['Sex '].isnull())]
# Out:
#        Case Number                  Date    Year        Type     Country  \
# 179   2017.02.01.b           01-Feb-2017  2017.0     Boating         usa
# 218   2016.09.15.R           15-Sep-2016  2016.0     Boating   australia
# 243     2016.07.17           17-Jul-2016  2016.0     Boating         usa
# 297     2016.03.13           13-Mar-2016  2016.0     Invalid         usa
# 326     2015.12.13           13-Dec-2015  2015.0     Boating   australia
# ...            ...                   ...     ...         ...         ...
# 6127  1804.02.26.R  Reported 26-Feb-1804  1804.0        Boat   australia
# 6136    1788.05.10           10-May-1788  1788.0        Boat   australia
# 6166  1637.00.00.R         Reported 1637  1637.0  Unprovoked       india
# 6167  1617.00.00.R         Reported 1617  1617.0  Unprovoked       india
# 6212       ND-0107           Before 2004     0.0        Boat  mozambique
#
#                     Area       Location              pais-oceano  \
# ...

# %%
data_sharks.isna().sum()
# Out:
# Case Number                  0
# Date                         0
# Year                         1
# Type                         2
# Country                      0
# Area                         0
# Location                     0
# pais-oceano                  0
# Activity                   395
# Name                        49
# Sex                        365
# Age                       2198
# Injury                      15
# Fatal (Y/N)                425
# Time                         0
# Species                   2307
# Investigator or Source      14
# pdf                          0
# href formula                 1
# href                         0
# Case Number.1                0
# Case Number.2                0
# original order               0
# dtype: int64

# %%
data_sharks['Name'].unique()
# Out:
# array(['Julie Wolfe', 'Adyson\xa0McNeely ', 'John Denges', ...,
#        '"youthful male"', 'a young Scotsman', 'A "chiefess"'],
#       dtype=object)

# %%
data_sharks[(data_sharks['Name'].isnull())]
# Out:
#          Case Number                  Date    Year          Type  \
# 184     2017.01.13.b           13-Jan-2017  2017.0    Unprovoked
# 721       2012.11.27           27-Nov-2012  2012.0       Invalid
# 866       2011.09.17           17-Sep-2011  2011.0    Unprovoked
# 882    2011.08.17.b.           17-Aug-2011  2011.0       Invalid
# 1107    2009.07.24.a           24-Jul-2009  2009.0       Invalid
# 1191    2008.11.09.b           09-Nov-2008  2008.0       Boating
# 1203      2008.09.14           14-Sep-2008  2008.0    Unprovoked
# 1321    2007.09.30.b           30-Sep-2007  2007.0  Sea Disaster
# 1327    2007.09.22.a           22-Sep-2007  2007.0    Unprovoked
# 1903      2001.09.13           13-Sep-2001  2001.0      Provoked
# 2149      1998.12.15           15-Dec-1998  1998.0    Unprovoked
# 2821      1986.04.00              Apr-1986  1986.0    Unprovoked
# 3130      1978.01.06           06-Jan-1978  1978.0       Invalid
# ...

# %%
data_sharks['Name'] = data_sharks['Name'].astype(str)
# Out:
# C:\Users\pepot\AppData\Local\Temp\ipykernel_9524\4196478150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sharks['Name'] = data_sharks['Name'].astype(str)

# %%
data_sharks['Sex '] = data_sharks['Sex '].astype(str)
# Out:
# C:\Users\pepot\AppData\Local\Temp\ipykernel_9524\401785123.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sharks['Sex '] = data_sharks['Sex '].astype(str)

# %%
for i, row in data_sharks.iterrows():
    if 'male' in row['Name']:
        data_sharks.at[i, 'Sex '] = 'M'
    elif 'female' in row['Name']:
        data_sharks.at[i, 'Sex '] = 'F'
    else:
        pass

# %%
data_sharks.shape
# Out:
# (5459, 23)

# %%
null_7=data_sharks[data_sharks['Name']== 'nan']
null_7.index
data_sharks.drop(null_7.index, inplace=True)
# Out:
# C:\Users\pepot\AppData\Local\Temp\ipykernel_9524\332269747.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sharks.drop(null_7.index, inplace=True)

# %%
null_8=data_sharks[data_sharks['Sex ']== 'nan']
null_8.index
data_sharks.drop(null_8.index, inplace=True)
# Out:
# C:\Users\pepot\AppData\Local\Temp\ipykernel_9524\3120878460.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sharks.drop(null_8.index, inplace=True)

# %%
data_sharks.shape
# Out:
# (5049, 23)

# %%
data_sharks['Sex '].unique()
# Out:
# array(['F', 'M', 'M ', 'lli', 'N'], dtype=object)

# %%
for i, row in data_sharks.iterrows():
    if 'M ' in row['Sex ']:
        data_sharks.at[i, 'Sex '] = 'M'
    else:
        pass

# %%
data_sharks['Sex '].unique()
# Out:
# array(['F', 'M', 'lli', 'N'], dtype=object)

# %%
null_9= data_sharks[data_sharks['Sex ']== 'lli']
null_9.index
data_sharks.drop(null_9.index, inplace=True)
# Out:
# C:\Users\pepot\AppData\Local\Temp\ipykernel_9524\1102812985.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sharks.drop(null_9.index, inplace=True)

# %%
null_10= data_sharks[data_sharks['Sex ']== 'N']
null_10.index
data_sharks.drop(null_10.index, inplace=True)
# Out:
# C:\Users\pepot\AppData\Local\Temp\ipykernel_9524\444172524.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sharks.drop(null_10.index, inplace=True)

# %% [markdown]
# # 10 voy a limpiar las columnas injury y Fatal(Y/N)

# %%
data_sharks[(data_sharks['Fatal (Y/N)'].isnull())]
# Out:
#        Case Number                   Date    Year        Type       Country  \
# 27    2018.04.15.c            15-Apr-2018  2018.0  Unprovoked        brazil
# 76      2017.10.01            01-Oct-2017  2017.0     Invalid  south africa
# 79    2017.09.24.b            24-Sep-2017  2017.0     Invalid           usa
# 84    2017.09.15.b            15-Sep-2017  2017.0     Invalid  south africa
# 98    2017.08.26.b            26-Aug-2017  2017.0     Invalid         spain
# ...            ...                    ...     ...         ...           ...
# 6046  1847.00.00.b                   1847  1847.0     Invalid           usa
# 6078  1837.00.00.a               Ca. 1837  1837.0     Invalid           usa
# 6088  1831.01.22.R  Reported 22- Jan-1831  1831.0     Invalid     australia
# 6147    1767.00.00                   1767  1767.0     Invalid        france
# 6232       ND.0081   No date, Before 1963     0.0     Invalid           usa
#
# ...

# %%
data_sharks['Sex '] = data_sharks['Sex '].astype(str)

# %%
for i, row in data_sharks.iterrows():
    if 'male' in row['Name']:
        data_sharks.at[i, 'Sex '] = 'M'
    elif 'female' in row['Name']:
        data_sharks.at[i, 'Sex '] = 'F'
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 rvqervervqervervqervervqerv
#
# NameError: name 'rvqervervqervervqervervqerv' is not defined

# %% [markdown]
# # PRUEBAS: voy a comparar la fila de country con Area y ver so puedo limpiar nulos o remplazar nulos por nombres

# %%
#porque no funciona
for e, row in data_sharks.iterrows():
    for e in data_sharks['Name']:
        if 'M' in row['Sex ']:
            data_sharks.at[e, 'nan'] = 'male'
        elif 'F' in row['Sex ']:
            data_sharks.at[e, 'nan'] = 'female'
        else:
            pass

# %%
data_sharks['Country'] = data_sharks['Country'].str.lower()cdvfdvfvfverfverfv

data_sharks.Country.unique()

# %%
name_f=data_sharks[data_sharks['Sex ']== 'nan']

# %%
name_f['Name'].unique()

# %%
data_sharks.apply(lambda row: row.contains('nan')).any(axis=1)

# %%
data_country=data_sharks[['Country', 'Area']]
data_country

# %%
data_missing=data_country[(data_country['Country'].isnull()) & (data_country['Area'].isnull())]
data_missing.index
#data_sharks.iloc[data_country[(data_country['Country'].isnull()) & (data_country['Area'].isnull())].index] (sirve para comprobar que la funcion que estoy haciendo esta bien)

# %%
data_country.drop(data_missing.index, inplace=True)

# %%
data_country

# %%
data_country.isna().sum()

# %%
data_country_1=data_sharks.iloc[data_country[(data_country['Country'].isnull())].index]
data_country_1

# %%
data_country_1.Area.unique()

# %%
data_country['Country'] = data_country['Country'].str.lower()

# %%
data_country.Country.unique()

# %%
mapeo_paises = {
    'English Channel': 'england',
    'Caribbean Sea': 'caribe',
    'Between Timor & Darwin, Australia': 'australia',
    'Near the Andaman & Nicobar Islands': 'india',
    'Between Comores & Madagascar': 'madagascar',
    'Off South American coast':'chile',
    '300 miles east of St. Thomas (Virgin Islands)': 'usa',
    'French Southern Territories': 'france',
    'Mediterranean Sea': 'spain',
    'Gulf of California': 'mexico',
    'Western Banks': 'australia',
    'St Helena': 'australia',
    'Ionian Sea': 'italy'
 }

# %%
mapeo_paises.get('St Helena')

# %%
mapeo_paises.get('australia', 'australia')

# %%
data_country_1.Country.apply(lambda x: data_country_1.get(x, x))

# %%
data_country_1

# %%
for i, e in mapeo_paises.items():
    if e in data_country_1.Country[e] == NaN:
        print()

# %%
data_country_1['Country'] = data_country_1['Area'].map(mapeo_paises)

# %%
data_country_1

# %%
for i in range (len(df)):
data_country_1.iloc[[0,0]
